# %% [markdown]
# ## Anomaly Visualization
#
# Anomaly visualizations were implemented in Power BI using aggregated datasets
# generated in `05_dashboard_data_prep.ipynb`.
#
# The dashboards include:
#
# - Anomaly KPIs
# - User risk rankings
# - Temporal anomaly trends
# - Anomaly type breakdowns
